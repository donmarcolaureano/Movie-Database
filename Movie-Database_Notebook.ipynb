# %%
import pandas as pd
import numpy as np

# %%
title_df = pd.read_csv('/Users/marcolaureano2/Documents/GitHub/Movie-Database/Data/title-akas-us-only.csv')
# Out:
# /var/folders/jx/cpydz30j3y523cvb2w4sjv7h0000gn/T/ipykernel_39227/4194135588.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   title_df = pd.read_csv('/Users/marcolaureano2/Documents/GitHub/Movie-Database/Data/title-akas-us-only.csv')

# %%
title_df
# Out:
#            titleId  ordering                                      title  \
# 0        tt0000001         6                                 Carmencita
# 1        tt0000002         7                     The Clown and His Dogs
# 2        tt0000005        10                           Blacksmith Scene
# 3        tt0000005         1                        Blacksmithing Scene
# 4        tt0000005         6                        Blacksmith Scene #1
# ...            ...       ...                                        ...
# 1452559  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 1452560  tt9916620         1                          The Copeland Case
# 1452561  tt9916702         1              Loving London: The Playground
# 1452562  tt9916756         1                   Pretty Pretty Black Girl
# 1452563  tt9916764         1                                         38
#
#         region language        types             attributes isOriginalTitle
# ...

# %%
title_df.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US       \N  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US       \N           \N
# 2  tt0000005        10        Blacksmith Scene     US       \N  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US       \N  alternative
#
#               attributes isOriginalTitle
# 0                     \N               0
# 1  literal English title               0
# 2                     \N               0
# 3                     \N               0
# 4                     \N               0

# %%
basics = pd.read_csv('/Users/marcolaureano2/Documents/GitHub/Movie-Database/Data/TitleBasics.tsv', sep='\t', low_memory=False)
basics
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10017006  tt9916848  tvEpisode              Episode #3.17
# 10017007  tt9916850  tvEpisode              Episode #3.19
# 10017008  tt9916852  tvEpisode              Episode #3.20
# 10017009  tt9916856      short                   The Wind
# 10017010  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# ...

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
filter_us_titles = basics['tconst'].isin(title_df['titleId'])
basics = basics[filter_us_titles]
basics
# Out:
#              tconst titleType                                 primaryTitle  \
# 0         tt0000001     short                                   Carmencita
# 1         tt0000002     short                       Le clown et ses chiens
# 4         tt0000005     short                             Blacksmith Scene
# 5         tt0000006     short                            Chinese Opium Den
# 6         tt0000007     short  Corbett and Courtney Before the Kinetograph
# ...             ...       ...                                          ...
# 10016872  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
# 10016901  tt9916620     movie                            The Copeland Case
# 10016939  tt9916702     short                Loving London: The Playground
# 10016962  tt9916756     short                     Pretty Pretty Black Girl
# 10016966  tt9916764     short                                           38
#
# ...

# %%
basics = basics.replace({'\\N':np.nan})
basics
# Out:
#              tconst titleType                                 primaryTitle  \
# 0         tt0000001     short                                   Carmencita
# 1         tt0000002     short                       Le clown et ses chiens
# 4         tt0000005     short                             Blacksmith Scene
# 5         tt0000006     short                            Chinese Opium Den
# 6         tt0000007     short  Corbett and Courtney Before the Kinetograph
# ...             ...       ...                                          ...
# 10016872  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
# 10016901  tt9916620     movie                            The Copeland Case
# 10016939  tt9916702     short                Loving London: The Playground
# 10016962  tt9916756     short                     Pretty Pretty Black Girl
# 10016966  tt9916764     short                                           38
#
# ...

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1365643 entries, 0 to 10016966
# Data columns (total 9 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   tconst          1365643 non-null  object
#  1   titleType       1365643 non-null  object
#  2   primaryTitle    1365643 non-null  object
#  3   originalTitle   1365643 non-null  object
#  4   isAdult         1365643 non-null  object
#  5   startYear       1266978 non-null  object
#  6   endYear         37130 non-null    object
#  7   runtimeMinutes  862524 non-null   object
#  8   genres          1337027 non-null  object
# dtypes: object(9)
# memory usage: 104.2+ MB

# %%
# Drop rows with null values in runtimeMinutes
basics = basics.dropna(subset='runtimeMinutes')
basics
# Out:
#              tconst titleType                                 primaryTitle  \
# 0         tt0000001     short                                   Carmencita
# 1         tt0000002     short                       Le clown et ses chiens
# 4         tt0000005     short                             Blacksmith Scene
# 5         tt0000006     short                            Chinese Opium Den
# 6         tt0000007     short  Corbett and Courtney Before the Kinetograph
# ...             ...       ...                                          ...
# 10016704  tt9916214     short                              Drown the Clown
# 10016724  tt9916254     video                         Big Tit Cream Pie 32
# 10016770  tt9916348     video                        Ancient World Exposed
# 10016777  tt9916362     movie                                        Coven
# 10016872  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
#
# ...

# %%
basics['titleType'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0             short
# 1             short
# 4             short
# 5             short
# 6             short
#              ...
# 10016704      short
# 10016724      video
# 10016770      video
# 10016777      movie
# 10016872    tvMovie
# Name: titleType, Length: 862524, dtype: object>

# %%
# Filter only full length movies
full_length_title = basics['titleType'] == 'movie'
basics = basics[full_length_title]
basics
# Out:
#              tconst titleType                    primaryTitle  \
# 8         tt0000009     movie                      Miss Jerry
# 144       tt0000147     movie   The Corbett-Fitzsimmons Fight
# 570       tt0000574     movie     The Story of the Kelly Gang
# 587       tt0000591     movie                The Prodigal Son
# 672       tt0000679     movie  The Fairylogue and Radio-Plays
# ...             ...       ...                             ...
# 10016366  tt9915436     movie               Vida em Movimento
# 10016544  tt9915872     movie            The Last White Witch
# 10016684  tt9916170     movie                   The Rehearsal
# 10016693  tt9916190     movie                       Safeguard
# 10016777  tt9916362     movie                           Coven
#
#                            originalTitle isAdult startYear endYear  \
# 8                             Miss Jerry       0      1894     NaN
# 144        The Corbett-Fitzsimmons Fight       0      1897     NaN
# ...

# %%
# convert startYear to float
basics['startYear'].dtype
# Out:
# dtype('O')

# %%
basics['startYear'] = basics['startYear'].astype(float)
# Out:
# /var/folders/jx/cpydz30j3y523cvb2w4sjv7h0000gn/T/ipykernel_39227/3352754901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics['startYear'] = basics['startYear'].astype(float)

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207381 entries, 8 to 10016777
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          207381 non-null  object
#  1   titleType       207381 non-null  object
#  2   primaryTitle    207381 non-null  object
#  3   originalTitle   207381 non-null  object
#  4   isAdult         207381 non-null  object
#  5   startYear       203770 non-null  float64
#  6   endYear         0 non-null       object
#  7   runtimeMinutes  207381 non-null  object
#  8   genres          203476 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 15.8+ MB

# %%
# Filter to keep movies >= 2000 and <= 2022
basics
# Out:
#              tconst titleType                    primaryTitle  \
# 8         tt0000009     movie                      Miss Jerry
# 144       tt0000147     movie   The Corbett-Fitzsimmons Fight
# 570       tt0000574     movie     The Story of the Kelly Gang
# 587       tt0000591     movie                The Prodigal Son
# 672       tt0000679     movie  The Fairylogue and Radio-Plays
# ...             ...       ...                             ...
# 10016366  tt9915436     movie               Vida em Movimento
# 10016544  tt9915872     movie            The Last White Witch
# 10016684  tt9916170     movie                   The Rehearsal
# 10016693  tt9916190     movie                       Safeguard
# 10016777  tt9916362     movie                           Coven
#
#                            originalTitle isAdult  startYear endYear  \
# 8                             Miss Jerry       0     1894.0     NaN
# 144        The Corbett-Fitzsimmons Fight       0     1897.0     NaN
# ...

# %%
basics['startYear'].nunique()
# Out:
# 128

# %%
under_2000 = basics['startYear'] <= 2000

# %%
under_2000.sum()
# Out:
# 79448

# %%
basics = basics[~under_2000]
basics
# Out:
#              tconst titleType  \
# 34802     tt0035423     movie
# 61114     tt0062336     movie
# 67666     tt0069049     movie
# 81515     tt0083324     movie
# 86793     tt0088751     movie
# ...             ...       ...
# 10016366  tt9915436     movie
# 10016544  tt9915872     movie
# 10016684  tt9916170     movie
# 10016693  tt9916190     movie
# 10016777  tt9916362     movie
#
#                                                primaryTitle  \
# 34802                                        Kate & Leopold
# 61114     The Tango of the Widower and Its Distorting Mi...
# 67666                            The Other Side of the Wind
# 81515                                       The White Lions
# 86793                                     The Naked Monster
# ...                                                     ...
# 10016366                                  Vida em Movimento
# 10016544                               The Last White Witch
# ...

# %%
over_2022 = basics['startYear'] >= 2022
over_2022
# Out:
# 34802       False
# 61114       False
# 67666       False
# 81515       False
# 86793       False
#             ...
# 10016366    False
# 10016544    False
# 10016684    False
# 10016693    False
# 10016777    False
# Name: startYear, Length: 127933, dtype: bool

# %%
over_2022.sum()
# Out:
# 10228

# %%
basics = basics[~over_2022]
basics
# Out:
#              tconst titleType  \
# 34802     tt0035423     movie
# 61114     tt0062336     movie
# 67666     tt0069049     movie
# 81515     tt0083324     movie
# 86793     tt0088751     movie
# ...             ...       ...
# 10016366  tt9915436     movie
# 10016544  tt9915872     movie
# 10016684  tt9916170     movie
# 10016693  tt9916190     movie
# 10016777  tt9916362     movie
#
#                                                primaryTitle  \
# 34802                                        Kate & Leopold
# 61114     The Tango of the Widower and Its Distorting Mi...
# 67666                            The Other Side of the Wind
# 81515                                       The White Lions
# 86793                                     The Naked Monster
# ...                                                     ...
# 10016366                                  Vida em Movimento
# 10016544                               The Last White Witch
# ...

# %%
basics['genres'].unique
# Out:
# <bound method Series.unique of 34802          Comedy,Fantasy,Romance
# 61114                           Drama
# 67666                           Drama
# 81515                           Drama
# 86793            Comedy,Horror,Sci-Fi
#                       ...
# 10016366                  Documentary
# 10016544         Comedy,Drama,Fantasy
# 10016684                        Drama
# 10016693    Action,Adventure,Thriller
# 10016777                Drama,History
# Name: genres, Length: 117705, dtype: object>

# %%
basics['genres'].value_counts()
# Out:
# Documentary                         20434
# Drama                               16463
# Comedy                               6810
# Horror                               3931
# Comedy,Drama                         3803
#                                     ...
# Adventure,History,Music                 1
# Adventure,History,War                   1
# Adventure,Documentary,Reality-TV        1
# Fantasy,Music,Sci-Fi                    1
# Mystery,Reality-TV,Thriller             1
# Name: genres, Length: 1047, dtype: int64

# %%
documentary_filter = basics['genres'] ==('Documentary')

# %%
basics = basics[~documentary_filter]
basics
# Out:
# /var/folders/jx/cpydz30j3y523cvb2w4sjv7h0000gn/T/ipykernel_39227/3111034911.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   basics = basics[~documentary_filter]
#              tconst titleType  \
# 34802     tt0035423     movie
# 61114     tt0062336     movie
# 67666     tt0069049     movie
# 81515     tt0083324     movie
# 86793     tt0088751     movie
# ...             ...       ...
# 10016225  tt9915130     movie
# 10016544  tt9915872     movie
# 10016684  tt9916170     movie
# 10016693  tt9916190     movie
# 10016777  tt9916362     movie
#
#                                                primaryTitle  \
# 34802                                        Kate & Leopold
# 61114     The Tango of the Widower and Its Distorting Mi...
# 67666                            The Other Side of the Wind
# 81515                                       The White Lions
# 86793                                     The Naked Monster
# ...

# %%
contains_documentary = basics['genres'].str.contains('Documentary')
contains_documentary.sum()
# Out:
# 12723
